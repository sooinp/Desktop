# %%
import pandas as pd #판다스를 pd로 명명
import numpy as np #넘파이를 np로 명명
#판다스는 표 형태의 데이터 다루기가 용이
#넘파이는 수치 연산에 적합한 라이브러리

#시리즈 = 값(value) + 인덱스(index)
#인덱스의 길이 = 데이터의 길이
#인덱스 값은 문자열 뿐 아니라 날짜, 시간, 정수 등도 가능

#리스트 = 파이썬 기본 자료구조
#시리즈 = 판다스의 1차원 자료구조

s = pd.Series([9904312, 3448737, 2890451, 2466052],
              index = ["서울", "부산", "인천", "대구"])
s
#s.index #s가 가진 인덱스가 뭔지 보여달라
#s.values #s가 가진 값이 뭔지 보여달라
#pd.Series(range(10,14))
s.name = "인구" #name 속성으로 전체이름
s.index.name = "도시" #index.name 속성으로 시리즈의 인덱스에도 이름 붙임
s

#시리즈 연산 - 시리즈는 벡터화 연산 가능
#연산은 시리즈 값에만 적용할 수 있고, 인덱스 값은 안변함
s/1000000


#리스트와 비교
#lst= [1,2,3]
#print("리스트연산 \n", lst*2)

#시리즈 인덱싱 - 인덱싱 라벨을 이용한 인덱싱,
s[2], s["부산"]
s[3], s["대구"]
s[3]

#자료순서 바꾸기
s[[0,3,1]]
s[["서울", "대구", "부산"]]

s[(250e4 < s) & (s < 500e4)] #인구가 250만 추가, 500만 미만인 경우
#조건을 넣을 수도 있다.

#슬라이싱 가능, 문자열일 경우, 콜론(:) 뒤에 오는 값도 결과에 포함
s[1:3] #두 번쨰 (1)부터 세번째(2)까지 (네 번쨰(3) 미포함)
s["부산":"대구"] #부산에서 대구까지 (대구도 포함)

#라벨 값이 영문 문자열인 경우 인덱스 라벨이 속성인것처럼 .을 이용해 해당 인덱스 값 접근 가능
s0 = pd.Series(range(3), index =["a", "b", "c"])
s0

s0.a
s0.c

s.부산
s.인천

#시리즈와 딕셔너리 자료혇
#시리즈 객체는 라벨 값에 의해 인덱싱이 가능하므로 실질적으로 인덱스 라벨 값을 키로 가지는 딕셔너리 자료형과
#같다고 볼 수 있음
"서울" in s #인덱스 라벨 중에 서울이 있는가
"대전" in s #인덱스 라밸 중에 대전이 있는가

#for k, v in s.items():
#  print("%s = %d" %(k,v))

#딕셔너리 객체에서 시리즈 만들기
s2 = pd.Series({"서울": 9631482, "부산": 3393191, "인천": 2632035, "대전": 1490158})
s2

#만약 순서를 정하고 싶다면 인덱스를 리스트로 지정해야 함
s2 = pd.Series({"서울": 9631482, "부산": 3393191, "인천": 2632035, "대전": 1490158},
               index=["부산", "서울", "인천", "대전"])
s2

#인덱스 기반 연산
#안댁스가 같은 데아터에 대해서만 계산 가능
ds = s - s2 # NaN <- Not a number 의미
ds

#null 값이 아닌 것 찾기 / 값 o - True
ds.notnull()
ds[ds.notnull()]

#증가율 계산
rs = (s - s2) / s2 * 100
rs = rs[rs.notnull()]
rs

#데이터의 갱신, 추가, 삭제
#인덱싱을 이용하면 딕셔너리 처럼 데이터를 갱신(update)하거나 추가
rs["부산"] = 1.63
rs
rs["대구"] = 1.41
rs

#데이터 삭제
del rs["대구"]
rs

#1 연습문제
#임의로 두 개의 시리즈 객체를 만든다. 모두 문자열 인덱스를 가져야하며 두 시리즈에 공통적으로
#포함되지 않는 라벨이 있어야한다.
#위에서 만든 두 시리즈 객체를 이용하여 사칙 연산을 한다.

nums1 = pd.Series([10, 20, 15, 10],
                  index =["감자", "고구마", "당근", "호박"])
nums1

nums2 = pd.Series([15, 15, 10, 15],
                  index = ["고구마", "감자", "당근", "연근"])
nums2

ds1 = nums1 - nums2
ds1.notnull()
ds2 = nums1 + nums2
ds2.notnull()

#print(ds1[ds1.notnull()])
#print(ds2[ds2.notnull()])

#데이터프레임
#2차원 리스트를 매개변수로 전달하는 구조
#2차원이므로 행방향 인덱스와 열방향 인덱스가 존재
#데이터프레임은 열까지 추가되어 열, 인덱스, 값으로 구성
#시리즈는 인덱스와 값으로 구성

values = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
index = ['one', 'two', 'three']
columns = ['A', 'B', 'C']

df = pd.DataFrame(values, index=index, columns=columns)

#print('데이터프레임 출력 :')
#print('-'*18)
#print(df)

#df1 = pd.DataFrame(values, columns=columns)
#print(df1)

#df2 = pd.DataFrame(values, index=index)
#print(df2)

#print(df.index)
#print(df.columns)
#print(df.values)

#데이터프레임의 생성
#1.리스트 2.시리즈 3.딕셔너리 4.Numpy의 ndarrays

#데이터프레임
# 리스트로 생성하기
data = [
    ['1000', 'Steve', 90.72],
    ['1001', 'James', 78.09],
    ['1002', 'Doyeon', 98.43],
    ['1003', 'Jane', 64.19],
    ['1004', 'Pilwoong', 81.30],
    ['1005', 'Tony', 99.14],
]

df = pd.DataFrame(data)
df
type(df)
df = pd.DataFrame(data, columns=['학번','이름','점수'])
df


# 딕셔너리로 생성하기
data = {
    "2015": [9904312, 3448737, 2890451, 2466052],
    "2010": [9631482, 3393191, 2632035, 2431774],
    "2005": [9762546, 3512547, 2517680, 2456016],
    "2000": [9853972, 3655437, 2466338, 2473990],
    "지역": ["수도권", "경상권", "수도권", "경상권"],
    "2010-2015 증가율": [0.0283, 0.0163, 0.0982, 0.0141]
}
columns = ["지역", "2015", "2010", "2005", "2000", "2010-2015 증가율"]
index = ["서울", "부산", "인천", "대구"]

df = pd.DataFrame(data, columns = columns, index = index)
df
df.values
df.columns
df.index

#전치가능(행렬 바꾸기)
df.T
df

#열 데이터의 갱신, 추가, 삭제
#데이터프레임은 열 시리즈의 딕셔너리로 볼 수 있으므로 열 단위로 데이터를 갱신하거나 추가, 삭제할 수 있음.
# "2010-2015 증가율"이라는 이름의 열 추가
df["2010-2015 증가율"] = df["2010-2015 증가율"] * 100
df
#"2005-2010 증가율"이라는 이름의 열 추가
df["2005-2010 증가율"] = ((df["2010"] - df["2005"])/df["2005"]*100).round(3)
df

#"2010-2015 증가율"이라는 이름의 열 삭제
del df["2010-2015 증가율"]
df

#열 인덱싱
#데이터프레임은 열 라벨을 키로, 열 시리즈를 값으로 가지는 딕셔너리와 비슷
#데이터프레임을 인덱싱 할 때도 열 라벨을 키값으로 생각하여 인덱싱 가능
#하나의 열만 인덱싱하면 시리즈가 반환된다.
df["지역"]
type(df["지역"])

#여러개의 열을 인덱싱하면 부분적인 데이터프레임이 반환된다.
df[["2010", "2015"]]
type(df[["2010", "2015"]])

df[["2010"]]
print(type(df[["2010"]]))
print(type(df["2010"]))
#문자열 라벨을 가지는 경우 정수 인덱스를 열 인덱싱에 사용할 수 없음
#df[0]

#열 인덱스가 정수형일땐 인덱스 값에 정수 사용 가능
#df2 = pd.DataFrame(np.arange(12).reshape(3,4))
#df2
#df2[2]
#df2[[1,2]]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# /tmp/ipython-input-2173285036.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[2], s["부산"]
# /tmp/ipython-input-2173285036.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[3], s["대구"]
# /tmp/ipython-input-2173285036.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[3]
# ...
