# %% [markdown]
# # 8장. 텍스트 빈도 분석 (1)영어단어분석

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (2.3.5)
# Requirement already satisfied: pillow in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python313\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl (300 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### - 자연어처리패키지 nltk download

# %%
! pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2025.11.3-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python313\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 62.3 MB/s  0:00:00
# Downloading regex-2025.11.3-cp313-cp313-win_amd64.whl (277 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk
#
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ------------------------ --------------- 3/5 [click]
#    ------------------------ --------------- 3/5 [click]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    ---------------------------------------- 5/5 [nltk]
#
# Successfully installed click-8.3.1 joblib-1.5.2 nltk-3.9.2 regex-2025.11.3 tqdm-4.67.1
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# #### -----------------------------------------------------------------

# %% [markdown]
# # 4. 데이터 준비

# %%
import pandas as pd
import glob
import re
from functools import reduce

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud

# %% [markdown]
# ## 데이터 조합 – 파일 병합하기

# %%
all_files = glob.glob('./8장_data/myCabinetExcelData*.xlsx')
all_files #출력하여 내용 확인
# Out:
# ['./8장_data\\myCabinetExcelData (1).xlsx',
#  './8장_data\\myCabinetExcelData (2).xlsx',
#  './8장_data\\myCabinetExcelData (3).xlsx',
#  './8장_data\\myCabinetExcelData (4).xlsx',
#  './8장_data\\myCabinetExcelData (5).xlsx',
#  './8장_data\\myCabinetExcelData (6).xlsx',
#  './8장_data\\myCabinetExcelData (7).xlsx',
#  './8장_data\\myCabinetExcelData (8).xlsx',
#  './8장_data\\myCabinetExcelData (9).xlsx',
#  './8장_data\\myCabinetExcelData.xlsx']

# %%
#"ImportError: Missing optional dependency 'xlrd'." 에러 발생 시, xlrd 패키지 설치하기
# !pip install xlrd

# %%
all_files_data = [] #저장할 리스트
for file in all_files:
    data_frame = pd.read_excel(file)
    all_files_data.append(data_frame)
    
all_files_data[0] #작업 내용 확인
# Out:
#     Unnamed: 0   번호                                                 제목  \
# 0          NaN    1  Call for Special Issue Papers: Soft Computing ...
# 1          NaN    2  Big Data, Efficient Markets, and the End of Da...
# 2          NaN    3   Big Data and Predictive Analytics in Health Care
# 3          NaN    4  Call for Special Issue Papers: Internet of Med...
# 4          NaN    5                         Big Data Literature Search
# ..         ...  ...                                                ...
# 95         NaN   96  A survey on big data processing infrastructure...
# 96         NaN   97  Toward Efficient and Flexible Metadata Indexin...
# 97         NaN   98  Distributed Feature Selection for Efficient Ec...
# 98         NaN   99  A platform for big data analytics on distribut...
# 99         NaN  100  Towards quality-of-service driven consistency ...
#
#                                                    저자               출판사   출판일
# 0      Chilamkurti, Naveen; Paul, Anand; Kumar, Akshi  Mary Ann Leibert  2020
# 1                   Urbaczewski, Andrew; Elmore, Ryan  Mary Ann Leibert  2018
# 2                                             unknown  Mary Ann Leibert  2014
# 3   Din, Sadia; Aslan, Nauman; Cheung, Simon K.S.;...  Mary Ann Leibert  2020
# 4                                             unknown  Mary Ann Leibert  2014
# ..                                                ...               ...   ...
# 95  Nunna, Krishna Chaitanya; Mehdipour, Farhad; T...      Inderscience  2015
# 96  Zhao, D.; Qiao, K.; Zhou, Z.; Li, T.; Lu, Z.; ...           unknown  2017
# 97     Zhao, L.; Chen, Z.; Hu, Y.; Min, G.; Jiang, Z.           unknown  2018
# 98                      Aye, Kyar Nyo; Thein, Thandar      Inderscience  2015
# 99  García-Recuero, Álvaro; Esteves, Sérgio; Veiga...      Inderscience  2014
#
# [100 rows x 6 columns]

# %%
all_files_data_concat = pd.concat( all_files_data, axis = 0, ignore_index = True)
all_files_data_concat #출력하여 내용 확인
# Out:
#      Unnamed: 0   번호                                                 제목  \
# 0           NaN    1  Call for Special Issue Papers: Soft Computing ...
# 1           NaN    2  Big Data, Efficient Markets, and the End of Da...
# 2           NaN    3   Big Data and Predictive Analytics in Health Care
# 3           NaN    4  Call for Special Issue Papers: Internet of Med...
# 4           NaN    5                         Big Data Literature Search
# ..          ...  ...                                                ...
# 995         NaN   96  Big data analysis of swimming pools' impact on...
# 996         NaN   97  MonkeyKing: Adaptive Parameter Tuning on Big D...
# 997         NaN   98  Curating Big Data Made Simple: Perspectives fr...
# 998         NaN   99               Big Data 2.0: Cataclysm or Catalyst?
# 999         NaN  100  Does Medical School Training Relate to Practic...
#
#                                                     저자               출판사   출판일
# 0       Chilamkurti, Naveen; Paul, Anand; Kumar, Akshi  Mary Ann Leibert  2020
# 1                    Urbaczewski, Andrew; Elmore, Ryan  Mary Ann Leibert  2018
# 2                                              unknown  Mary Ann Leibert  2014
# 3    Din, Sadia; Aslan, Nauman; Cheung, Simon K.S.;...  Mary Ann Leibert  2020
# 4                                              unknown  Mary Ann Leibert  2014
# ..                                                 ...               ...   ...
# 995  Elnakat, Afamia; Gomez, Juan D.; Roberts, Jaso...      Inderscience  2015
# 996  Du, Haizhou; Han, Ping; Xiang, Qiao; Huang, Sheng  Mary Ann Leibert  2020
# 997                                            unknown  Mary Ann Leibert  2014
# 998                                            unknown  Mary Ann Leibert  2014
# 999                                            unknown  Mary Ann Leibert  2015
#
# [1000 rows x 6 columns]

# %%
all_files_data_concat.to_csv( '8장_data/riss_bigdata.csv', encoding = 'utf-8', index = False)

# %% [markdown]
# ## 데이터 전처리

# %%
all_title = all_files_data_concat['제목']
all_title #출력하여 내용 확인
# Out:
# 0      Call for Special Issue Papers: Soft Computing ...
# 1      Big Data, Efficient Markets, and the End of Da...
# 2       Big Data and Predictive Analytics in Health Care
# 3      Call for Special Issue Papers: Internet of Med...
# 4                             Big Data Literature Search
#                              ...
# 995    Big data analysis of swimming pools' impact on...
# 996    MonkeyKing: Adaptive Parameter Tuning on Big D...
# 997    Curating Big Data Made Simple: Perspectives fr...
# 998                 Big Data 2.0: Cataclysm or Catalyst?
# 999    Does Medical School Training Relate to Practic...
# Name: 제목, Length: 1000, dtype: object

# %%
stopWords = set(stopwords.words("english"))
lemma = WordNetLemmatizer()

# %%
words = []
for title in all_title:
    EnWords = re.sub(r"[^a-zA-Z]+", " ", str(title))
    EnWordsToken = word_tokenize(EnWords.lower())
    EnWordsTokenStop = [ w for w in EnWordsToken if w not in stopWords]
    EnWordsTokenStopLemma = [ lemma.lemmatize(w) for w in EnWordsTokenStop]
    words.append(EnWordsTokenStopLemma)

# %%
print(words) #출력하여 내용 확인
# Out:
# [['call', 'special', 'issue', 'paper', 'soft', 'computing', 'model', 'big', 'data', 'internet', 'thing'], ['big', 'data', 'efficient', 'market', 'end', 'daily', 'fantasy', 'sport', 'know'], ['big', 'data', 'predictive', 'analytics', 'health', 'care'], ['call', 'special', 'issue', 'paper', 'internet', 'medical', 'thing', 'big', 'data', 'pervasive', 'medical', 'care'], ['big', 'data', 'literature', 'search'], ['big', 'data', 'ensemble', 'clinical', 'prediction', 'healthcare', 'data', 'using', 'deep', 'learning', 'model'], ['call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'industrial', 'intelligence'], ['u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise'], ['exploiting', 'reused', 'based', 'sharing', 'work', 'opportunity', 'big', 'data', 'multiquery', 'optimization', 'flink'], ['big', 'data', 'machine', 'analyze', 'stock', 'market', 'sentiment'], ['overcoming', 'resistance', 'big', 'data', 'operational', 'change', 'interactive', 'data', 'visualization'], ['call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education'], ['big', 'data', 'lost', 'cloud'], ['call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot'], ['big', 'data', 'social', 'good'], ['big', 'data', 'rise', 'machine', 'financial', 'market'], ['big', 'data', 'support', 'sustainable', 'development', 'goal', 'continued', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management'], ['big', 'data', 'based', 'security', 'analytics', 'protecting', 'virtualized', 'infrastructure', 'cloud', 'computing'], ['tv', 'audience', 'measurement', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity'], ['new', 'discrimination', 'diagram', 'basalt', 'based', 'big', 'data', 'research'], ['ensemble', 'based', 'scalable', 'approach', 'intrusion', 'detection', 'using', 'big', 'data', 'framework'], ['data', 'science', 'oceanography', 'small', 'data', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management'], ['big', 'data', 'enabler', 'primary', 'education'], ['big', 'multimodal', 'data', 'analysis', 'model', 'performance', 'analysis'], ['efficient', 'ensemble', 'based', 'classification', 'framework', 'big', 'medical', 'data'], ['unsupervised', 'tensor', 'mining', 'big', 'data', 'practitioner'], ['big', 'data', 'analytics', 'data', 'management', 'perspective', 'public', 'administration'], ['comparison', 'scalability', 'batch', 'big', 'data', 'processing', 'apache', 'spark', 'apache', 'flink'], ['big', 'data', 'little', 'data', 'care', 'coordination', 'medicare', 'beneficiary', 'medigap', 'coverage'], ['rst', 'de', 'rough', 'set', 'based', 'new', 'differential', 'evolution', 'algorithm', 'scalable', 'big', 'data', 'feature', 'selection', 'distributed', 'computing', 'platform'], ['national', 'survey', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitor'], ['big', 'data', 'healthcare', 'opportunity', 'challenge'], ['big', 'data', 'lost', 'cloud'], ['big', 'data', 'application', 'guangzhou', 'restaurant', 'analysis'], ['call', 'special', 'issue', 'paper', 'programming', 'model', 'algorithm', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education'], ['online', 'analytical', 'processing', 'business', 'intelligence', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'soft', 'computing', 'model', 'big', 'data', 'internet', 'thing'], ['remotely', 'sensed', 'big', 'data', 'ocean', 'polar', 'region'], ['message', 'editor', 'chief', 'big', 'data'], ['inte ...

# %%
words2 = list(reduce(lambda x, y: x+y, words))
print(words2) #출력하여 내용 확인
# Out:
# ['call', 'special', 'issue', 'paper', 'soft', 'computing', 'model', 'big', 'data', 'internet', 'thing', 'big', 'data', 'efficient', 'market', 'end', 'daily', 'fantasy', 'sport', 'know', 'big', 'data', 'predictive', 'analytics', 'health', 'care', 'call', 'special', 'issue', 'paper', 'internet', 'medical', 'thing', 'big', 'data', 'pervasive', 'medical', 'care', 'big', 'data', 'literature', 'search', 'big', 'data', 'ensemble', 'clinical', 'prediction', 'healthcare', 'data', 'using', 'deep', 'learning', 'model', 'call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'industrial', 'intelligence', 'u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise', 'exploiting', 'reused', 'based', 'sharing', 'work', 'opportunity', 'big', 'data', 'multiquery', 'optimization', 'flink', 'big', 'data', 'machine', 'analyze', 'stock', 'market', 'sentiment', 'overcoming', 'resistance', 'big', 'data', 'operational', 'change', 'interactive', 'data', 'visualization', 'call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education', 'big', 'data', 'lost', 'cloud', 'call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot', 'big', 'data', 'social', 'good', 'big', 'data', 'rise', 'machine', 'financial', 'market', 'big', 'data', 'support', 'sustainable', 'development', 'goal', 'continued', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management', 'big', 'data', 'based', 'security', 'analytics', 'protecting', 'virtualized', 'infrastructure', 'cloud', 'computing', 'tv', 'audience', 'measurement', 'big', 'data', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity', 'new', 'discrimination', 'diagram', 'basalt', 'based', 'big', 'data', 'research', 'ensemble', 'based', 'scalable', 'approach', 'intrusion', 'detection', 'using', 'big', 'data', 'framework', 'data', 'science', 'oceanography', 'small', 'data', 'big', 'data', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management', 'big', 'data', 'enabler', 'primary', 'education', 'big', 'multimodal', 'data', 'analysis', 'model', 'performance', 'analysis', 'efficient', 'ensemble', 'based', 'classification', 'framework', 'big', 'medical', 'data', 'unsupervised', 'tensor', 'mining', 'big', 'data', 'practitioner', 'big', 'data', 'analytics', 'data', 'management', 'perspective', 'public', 'administration', 'comparison', 'scalability', 'batch', 'big', 'data', 'processing', 'apache', 'spark', 'apache', 'flink', 'big', 'data', 'little', 'data', 'care', 'coordination', 'medicare', 'beneficiary', 'medigap', 'coverage', 'rst', 'de', 'rough', 'set', 'based', 'new', 'differential', 'evolution', 'algorithm', 'scalable', 'big', 'data', 'feature', 'selection', 'distributed', 'computing', 'platform', 'national', 'survey', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitor', 'big', 'data', 'healthcare', 'opportunity', 'challenge', 'big', 'data', 'lost', 'cloud', 'big', 'data', 'application', 'guangzhou', 'restaurant', 'analysis', 'call', 'special', 'issue', 'paper', 'programming', 'model', 'algorithm', 'big', 'data', 'call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education', 'online', 'analytical', 'processing', 'business', 'intelligence', 'big', 'data', 'call', 'special', 'issue', 'paper', 'soft', 'computing', 'model', 'big', 'data', 'internet', 'thing', 'remotely', 'sensed', 'big', 'data', 'ocean', 'polar', 'region', 'message', 'editor', 'chief', 'big', 'data', 'intelligent', 'big', 'data', 'analysis', 'review', 'agile', 'big', 'data', 'analytics', 'web' ...

# %% [markdown]
# # 5. 데이터 탐색 및 분석 모델 구축

# %% [markdown]
# ## 1. 데이터 탐색 - 단어 빈도 구하기

# %%
count = Counter(words2)
count #출력하여 내용 확인
# Out:
# Counter({'data': 1239,
#          'big': 1112,
#          'analytics': 113,
#          'based': 102,
#          'analysis': 97,
#          'driven': 71,
#          'system': 62,
#          'using': 56,
#          'approach': 56,
#          'issue': 48,
#          'learning': 48,
#          'model': 46,
#          'challenge': 44,
#          'application': 40,
#          'new': 39,
#          'special': 37,
#          'management': 36,
#          'framework': 36,
#          'algorithm': 36,
#          'call': 34,
#          'research': 34,
#          'science': 34,
#          'platform': 34,
#          'paper': 32,
#          'health': 31,
#          'cloud': 30,
#          'era': 30,
#          'opportunity': 28,
#          'network': 27,
#          'machine': 26,
#          'mining': 26,
#          'processing': 26,
#          'technology': 26,
#          'computing': 25,
#          'performance': 25,
#          'method': 25,
#          'earth': 25,
#          'optimization': 24,
#          'perspective': 24,
#          'business': 24,
#          'smart': 24,
#          'distributed': 23,
#          'information': 23,
#          'use': 23,
#          'review': 22,
#          'process': 22,
#          'world': 22,
#          'intelligence': 21,
#          'service': 21,
#          'development': 20,
#          'real': 20,
#          'study': 20,
#          'survey': 19,
#          'china': 19,
#          'internet': 18,
#          'efficient': 18,
#          'small': 18,
#          'time': 18,
#          'future': 18,
#          'energy': 18,
#          'social': 17,
#          'sustainable': 17,
#          'industry': 17,
#          'healthcare': 16,
#          'security': 16,
#          'editorial': 16,
#          'decision': 16,
#          'digital': 16,
#          'thing': 15,
#          'medical': 15,
#          'prediction': 15,
#          'making': 15,
#          'intelligent': 14,
#          'scalable': 14,
#          'medium': 14,
#          'impact': 14,
#          'risk': 14,
#          'deep': 13,
#          'environment': 13,
#          'engineering': 13,
#          'online': 13,
#          'case': 13,
#          'guest': 13,
#          'discovery': 13,
#          'understanding': 13,
#          'scale': 13,
#          'role': 13,
#          'large': 13,
#          'high': 13,
#          'patient': 13,
#          'support': 12,
#          'goal': 12,
#          'infrastructure': 12,
#          'detection': 12,
#          'architecture': 12,
#          'solution': 12,
#          'towards': 12,
#          'knowledge': 12,
#          'monitoring': 12,
#          'multi': 12,
#          'modeling': 12,
#          'state': 12,
#          'privacy': 12,
#          'control': 12,
#          'problem': 12,
#          'revolution': 12,
#          'care': 11,
#          'clinical': 11,
#          'classification': 11,
#          'clustering': 11,
#          'pattern': 11,
#          'human': 11,
#          'assessment': 11,
#          'design': 11,
#          'innovation': 11,
#          'technique': 11,
#          'practice': 11,
#          'sharing': 10,
#          'work': 10,
#          'financial': 10,
#          'little': 10,
#          'distribution': 10,
#          'trend': 10,
#          'value': 10,
#          'via': 10,
#          'scientific': 10,
#          'scheduling': 10,
#          'database': 10,
#          'strategy': 10,
#          'capability': 10,
#          'evidence': 10,
#          'market': 9,
#          'iot': 9,
#          'education': 9,
#          'public': 9,
#          'selection': 9,
#          'current': 9,
#          'storage': 9,
#          'context': 9,
#          'k': 9,
#          'enabled': 9,
#          'global': 9,
#          'insight': 9,
#          'green': 9,
#          'statistical': 9,
#          'r': 9,
#          'policy': 9,
#          'improve': 9,
#          'industrial': 8,
#          'u': 8,
#          'web': 8,
#          'potential': 8,
#          'quality': 8,
#          'behavior': 8,
#          'novel': 8,
#          'city': 8,
#          'computational': 8,
#          'dynamic': 8,
#          'mapreduce': 8,
#          'building': 8,
#          'device': 8,
#          'implication': 8,
#          'transformation': 8,
#          'generation': 8,
#          'safety': 8,
#          'drug': 8,
#          'question': 8,
#          'medicine': 8,
#          'disease': 8,
#          'mean': 8,
#          'predictive': 7,
#          'search': 7,
#          'enterprise': 7,
#          'visualization': 7,
#          'center': 7,
#          'measurement': 7,
#          'mobile': 7,
#          'leveraging': 7,
#          'transportation': 7,
#          'fuzzy': 7,
#          'aware': 7,
#          'e': 7,
#          'recommendation': 7,
#          'sensor': 7,
#          'toward': 7,
#          'parallel': 7,
#          'memory': 7,
#          'grid': 7,
#          'chain': 7,
#          'sensing': 7,
#          'spatial': 7,
#          'mapping': 7,
#          'sector': 7,
#          'power': 7,
#          'exploring': 7,
#          'advanced': 7,
#          'competitive': 7,
#          'vehicle': 7,
#          'promise': 7,
#          'next': 7,
#          'relationship': 7,
#          'political': 7,
#          'company': 7,
#          'environmental': 7,
#          'help': 7,
#          'think': 7,
#          'intensity': 7,
#          'nasopharyngeal': 7,
#          'carcinoma': 7,
#          'radiotherapy': 7,
#          'scholarship': 7,
#          'transform': 7,
#          'good': 6,
#          'international': 6,
#          'disaster': 6,
#          'feature': 6,
#          'analyzing': 6,
#          'index': 6,
#          'collaboration': 6,
#          'adaptive': 6,
#          'scheme': 6,
#          'resource': 6,
#          'estimation': 6,
#          'urban': 6,
#          'semantic': 6,
#          'way': 6,
#          'open': 6,
#          'supply': 6,
#          'meet': 6,
#          'error': 6,
#          'benefit': 6,
#          'evaluation': 6,
#          'wireless': 6,
#          'communication': 6,
#          'manufacturing': 6,
#          'firm': 6,
#          'predicting': 6,
#          'product': 6,
#          'uncertainty': 6,
#          'oriented': 6,
#          'access': 6,
#          'field': 6,
#          'electric': 6,
#          'production': 6,
#          'government': 6,
#          'critical': 6,
#          'efficiency': 6,
#          'covid': 6,
#          'marketing': 6,
#          'moving': 6,
#          'und': 6,
#          'age': 6,
#          'finding': 6,
#          'introduction': 6,
#          'customer': 6,
#          'networked': 6,
#          'literature': 5,
#          'sentiment': 5,
#          'multimedia': 5,
#          'agricultural': 5,
#          'spark': 5,
#          'national': 5,
#          'user': 5,
#          'improved': 5,
#          'recent': 5,
#          'scholarly': 5,
#          'image': 5,
#          'governance': 5,
#          'theory': 5,
#          'temporal': 5,
#          'allocation': 5,
#          'heterogeneous': 5,
#          'kernel': 5,
#          'managing': 5,
#          'operation': 5,
#          'observation': 5,
#          'graph': 5,
#          'space': 5,
#          'map': 5,
#          'transforming': 5,
#          'integration': 5,
#          'forecasting': 5,
#          'compression': 5,
#          'used': 5,
#          'project': 5,
#          'fusion': 5,
#          'status': 5,
#          'team': 5,
#          'warehouse': 5,
#          'deal': 5,
#          'mobility': 5,
#          'incremental': 5,
#          'non': 5,
#          'group': 5,
#          'theoretical': 5,
#          'approximation': 5,
#          'identification': 5,
#          'series': 5,
#          'advantage': 5,
#          'car': 5,
#          'software': 5,
#          'der': 5,
#          'advance': 5,
#          'artificial': 5,
#          'cluster': 5,
#          'f': 5,
#          'flow': 5,
#          'accurate': 5,
#          'diagnosis': 5,
#          'united': 5,
#          'politics': 5,
#          'offer': 5,
#          'cancer': 5,
#          'dementia': 5,
#          'assisted': 5,
#          'alzheimer': 5,
#          'live': 5,
#          'sport': 4,
#          'ensemble': 4,
#          'cognitive': 4,
#          'stock': 4,
#          'cybersecurity': 4,
#          'tensor': 4,
#          'apache': 4,
#          'set': 4,
#          'evolution': 4,
#          'population': 4,
#          'message': 4,
#          'overview': 4,
#          'news': 4,
#          'enhanced': 4,
#          'reference': 4,
#          'handling': 4,
#          'stream': 4,
#          'air': 4,
#          'nosql': 4,
#          'perception': 4,
#          'content': 4,
#          'hybrid': 4,
#          'frontier': 4,
#          'view': 4,
#          'semantics': 4,
#          'evaluating': 4,
#          'utilization': 4,
#          'processor': 4,
#          'remote': 4,
#          'visual': 4,
#          'sampling': 4,
#          'bayesian': 4,
#          'phase': 4,
#          'hadoop': 4,
#          'nearest': 4,
#          'practical': 4,
#          'ai': 4,
#          'query': 4,
#          'sparse': 4,
#          'cell': 4,
#          'tool': 4,
#          'physical': 4,
#          'applying': 4,
#          'librarian': 4,
#          'implementation': 4,
#          'rule': 4,
#          'bibliometric': 4,
#          'methodology': 4,
#          'multiple': 4,
#          'v': 4,
#          'correction': 4,
#          'dimension': 4,
#          'supporting': 4,
#          'factor': 4,
#          'law': 4,
#          'student': 4,
#          'make': 4,
#          'material': 4,
#          'lesson': 4,
#          'growth': 4,
#          'conceptual': 4,
#          'gene': 4,
#          'oil': 4,
#          'emergence': 4,
#          'discussion': 4,
#          'key': 4,
#          'child': 4,
#          'becoming': 4,
#          'tracking': 4,
#          'price': 4,
#          'optimizing': 4,
#          'biology': 4,
#          'gathering': 4,
#          'need': 4,
#          'stochastic': 4,
#          'interconnection': 4,
#          'cost': 4,
#          'deadline': 4,
#          'audit': 4,
#          'life': 4,
#          'epidemiology': 4,
#          'text': 4,
#          'complex': 4,
#          'modulated': 4,
#          'top': 4,
#          'association': 4,
#          'self': 4,
#          'p': 4,
#          'provides': 4,
#          'asset': 4,
#          'look': 4,
#          'pp': 4,
#          'isbn': 4,
#          'school': 4,
#          'economy': 4,
#          'futuristic': 4,
#          'fabric': 4,
#          'societal': 4,
#          'exploiting': 3,
#          'resistance': 3,
#          'operational': 3,
#          'change': 3,
#          'continued': 3,
#          'establishment': 3,
#          'programming': 3,
#          'region': 3,
#          'editor': 3,
#          'modelling': 3,
#          'interval': 3,
#          'scholar': 3,
#          'landscape': 3,
#          'extraction': 3,
#          'corporate': 3,
#          'fraud': 3,
#          'report': 3,
#          'behavioral': 3,
#          'classifier': 3,
#          'anomaly': 3,
#          'structural': 3,
#          'commerce': 3,
#          'rating': 3,
#          'simulation': 3,
#          'secure': 3,
#          'five': 3,
#          'extended': 3,
#          'spatio': 3,
#          'demand': 3,
#          'pipeline': 3,
#          'preserving': 3,
#          'vector': 3,
#          'flexible': 3,
#          'fast': 3,
#          'independent': 3,
#          'deduplication': 3,
#          'concern': 3,
#          'comprehensive': 3,
#          'geospatial': 3,
#          'first': 3,
#          'experience': 3,
#          'core': 3,
#          'generalized': 3,
#          'google': 3,
#          'engine': 3,
#          'improving': 3,
#          'bigger': 3,
#          'biggest': 3,
#          'neighbor': 3,
#          'culture': 3,
#          'paradigm': 3,
#          'leverage': 3,
#          'initiative': 3,
#          'mine': 3,
#          'better': 3,
#          'collection': 3,
#          'dimensional': 3,
#          'matrix': 3,
#          'grand': 3,
#          'investigation': 3,
#          'swarm': 3,
#          'reduction': 3,
#          'dream': 3,
#          'emerging': 3,
#          'scenario': 3,
#          'regional': 3,
#          'analysing': 3,
#          'stakeholder': 3,
#          'twitter': 3,
#          'community': 3,
#          'aggregation': 3,
#          'store': 3,
#          'hot': 3,
#          'order': 3,
#          'course': 3,
#          'candidate': 3,
#          'spectrum': 3,
#          'screening': 3,
#          'concept': 3,
#          'boost': 3,
#          'workflow': 3,
#          'comparative': 3,
#          'carbon': 3,
#          'informatics': 3,
#          'prevention': 3,
#          'c': 3,
#          'edge': 3,
#          'x': 3,
#          'imaging': 3,
#          'activity': 3,
#          'consideration': 3,
#          'ecology': 3,
#          'ethic': 3,
#          'logistics': 3,
#          'dissemination': 3,
#          'pharmaceutical': 3,
#          'pandemic': 3,
#          'sleep': 3,
#          'tree': 3,
#          'pain': 3,
#          'target': 3,
#          'ground': 3,
#          'expanding': 3,
#          'response': 3,
#          'putting': 3,
#          'gpu': 3,
#          'nonvolatile': 3,
#          'domain': 3,
#          'organizational': 3,
#          'code': 3,
#          'interview': 3,
#          'mit': 3,
#          'zum': 3,
#          'analyse': 3,
#          'agenda': 3,
#          'ownership': 3,
#          'fine': 3,
#          'exascale': 3,
#          'randomized': 3,
#          'qualitative': 3,
#          'therapy': 3,
#          'asia': 3,
#          'anatomy': 3,
#          'action': 3,
#          'forward': 3,
#          'wide': 3,
#          'hospital': 3,
#          'among': 3,
#          'mental': 3,
#          'area': 3,
#          'unit': 3,
#          'anti': 3,
#          'utility': 3,
#          'outcome': 3,
#          'start': 3,
#          'treatment': 3,
#          'general': 3,
#          'size': 3,
#          'associated': 3,
#          'filter': 3,
#          'donepezil': 3,
#          'comorbidity': 3,
#          'japan': 3,
#          'made': 3,
#          'gain': 3,
#          'lawyer': 3,
#          'amp': 3,
#          'protection': 3,
#          'personal': 3,
#          'christine': 3,
#          'l': 3,
#          'borgman': 3,
#          'water': 3,
#          'marketer': 3,
#          'training': 3,
#          'internal': 3,
#          'press': 3,
#          'create': 3,
#          'optimize': 3,
#          'pediatric': 3,
#          'brother': 3,
#          'intensive': 3,
#          'tourism': 3,
#          'personalized': 3,
#          'philosophy': 3,
#          'attack': 3,
#          'genomics': 3,
#          'shift': 3,
#          'geoinformatics': 3,
#          'circular': 3,
#          'guideline': 3,
#          'trauma': 3,
#          'game': 3,
#          'beyond': 3,
#          'propaganda': 3,
#          'biomedical': 3,
#          'robotics': 3,
#          'soft': 2,
#          'end': 2,
#          'army': 2,
#          'flink': 2,
#          'analyze': 2,
#          'interactive': 2,
#          'lost': 2,
#          'rise': 2,
#          'celebration': 2,
#          'cbas': 2,
#          'discrimination': 2,
#          'primary': 2,
#          'multimodal': 2,
#          'practitioner': 2,
#          'administration': 2,
#          'comparison': 2,
#          'batch': 2,
#          'coverage': 2,
#          'de': 2,
#          'analytical': 2,
#          'ocean': 2,
#          'centric': 2,
#          'metering': 2,
#          'telecom': 2,
#          'influence': 2,
#          'finance': 2,
#          'datasets': 2,
#          'patent': 2,
#          'consistency': 2,
#          'trajectory': 2,
#          'optimized': 2,
#          'eeg': 2,
#          'ieee': 2,
#          'transaction': 2,
#          'vol': 2,
#          'balance': 2,
#          'similarity': 2,
#          'reconstruction': 2,
#          'extracting': 2,
#          'shared': 2,
#          'layer': 2,
#          'taxi': 2,
#          'fmri': 2,
#          'svm': 2,
#          'evolving': 2,
#          'metadata': 2,
#          'composition': 2,
#          'provision': 2,
#          'semantically': 2,
#          'relevant': 2,
#          'thermal': 2,
#          'task': 2,
#          'ethical': 2,
#          'interoperability': 2,
#          'ontology': 2,
#          'co': 2,
#          'geo': 2,
#          'supervised': 2,
#          'belt': 2,
#          'climate': 2,
#          'transport': 2,
#          'sentinel': 2,
#          'landsat': 2,
#          'blood': 2,
#          'donation': 2,
#          'educational': 2,
#          'reduce': 2,
#          'repository': 2,
#          'level': 2,
#          'coping': 2,
#          'moderating': 2,
#          'organisation': 2,
#          'regression': 2,
#          'divide': 2,
#          'early': 2,
#          'designing': 2,
#          'yield': 2,
#          'condition': 2,
#          'build': 2,
#          'em': 2,
#          'reducing': 2,
#          'volume': 2,
#          'electrophysiology': 2,
#          'criminal': 2,
#          'peer': 2,
#          'implicit': 2,
#          'portfolio': 2,
#          'experimental': 2,
#          'cyber': 2,
#          'academic': 2,
#          'skill': 2,
#          'conference': 2,
#          'belief': 2,
#          'catalyst': 2,
#          'michael': 2,
#          'buck': 2,
#          'compute': 2,
#          'relation': 2,
#          'barrier': 2,
#          'optimal': 2,
#          'comparing': 2,
#          'effect': 2,
#          'computation': 2,
#          'success': 2,
#          'mr': 2,
#          'holistic': 2,
#          'advancing': 2,
#          'convergent': 2,
#          'simple': 2,
#          'pre': 2,
#          'bias': 2,
#          'sample': 2,
#          'direction': 2,
#          'ecosystem': 2,
#          'virtual': 2,
#          'genome': 2,
#          'sequence': 2,
#          'decomposition': 2,
#          'join': 2,
#          'contextual': 2,
#          'localization': 2,
#          'effective': 2,
#          'recovery': 2,
#          'correlation': 2,
#          'imputation': 2,
#          'gaussian': 2,
#          'factorization': 2,
#          'face': 2,
#          'simplified': 2,
#          'mo': 2,
#          'oracle': 2,
#          'sparc': 2,
#          'hardware': 2,
#          'also': 2,
#          'enable': 2,
#          'working': 2,
#          'ready': 2,
#          'latest': 2,
#          'transfer': 2,
#          'throughput': 2,
#          'three': 2,
#          'aerial': 2,
#          'scanning': 2,
#          'satellite': 2,
#          'influencing': 2,
#          'protein': 2,
#          'structure': 2,
#          'bioinformatics': 2,
#          'type': 2,
#          'expression': 2,
#          'consumption': 2,
#          'smallholder': 2,
#          'possibility': 2,
#          'capital': 2,
#          'film': 2,
#          'drive': 2,
#          'meter': 2,
#          'sensitivity': 2,
#          'individual': 2,
#          'track': 2,
#          'neural': 2,
#          'stem': 2,
#          'empirical': 2,
#          'credit': 2,
#          'mechanism': 2,
#          'warehousing': 2,
#          'program': 2,
#          'capturing': 2,
#          'laboratory': 2,
#          'targeted': 2,
#          'available': 2,
#          'doi': 2,
#          'increased': 2,
#          'animal': 2,
#          'encryption': 2,
#          'cryptography': 2,
#          'worker': 2,
#          'warning': 2,
#          'south': 2,
#          'korea': 2,
#          'surface': 2,
#          'fitting': 2,
#          'aircraft': 2,
#          'researcher': 2,
#          'say': 2,
#          'job': 2,
#          'employee': 2,
#          'savvy': 2,
#          'traditional': 2,
#          'edited': 2,
#          'st': 2,
#          'still': 2,
#          'unmanned': 2,
#          'routing': 2,
#          'bike': 2,
#          'dual': 2,
#          'charging': 2,
#          'cover': 2,
#          'pressure': 2,
#          'jbhi': 2,
#          'enhancing': 2,
#          'workload': 2,
#          'pmu': 2,
#          'rethink': 2,
#          'career': 2,
#          'graduate': 2,
#          'abnormal': 2,
#          'w': 2,
#          'waste': 2,
#          'detect': 2,
#          'diabetes': 2,
#          'von': 2,
#          'emergency': 2,
#          'planning': 2,
#          'starting': 2,
#          'cross': 2,
#          'failure': 2,
#          'traffic': 2,
#          'thema': 2,
#          'convergence': 2,
#          'hat': 2,
#          'must': 2,
#          'identifying': 2,
#          'purpose': 2,
#          'pr': 2,
#          'seeking': 2,
#          'dividend': 2,
#          'joining': 2,
#          'eva': 2,
#          'style': 2,
#          'pitfall': 2,
#          'phylogenetics': 2,
#          'ad': 2,
#          'land': 2,
#          'position': 2,
#          'tech': 2,
#          'insurance': 2,
#          'ist': 2,
#          'proxy': 2,
#          'statistic': 2,
#          'distance': 2,
#          'stability': 2,
#          'convex': 2,
#          'common': 2,
#          'genetic': 2,
#          'best': 2,
#          'get': 2,
#          'short': 2,
#          'trade': 2,
#          'informed': 2,
#          'travel': 2,
#          'article': 2,
#          'singapore': 2,
#          'mhc': 2,
#          'crunch': 2,
#          'leadership': 2,
#          'hacker': 2,
#          'behave': 2,
#          'brain': 2,
#          'mortality': 2,
#          'admission': 2,
#          'adult': 2,
#          'determinant': 2,
#          'long': 2,
#          'endemic': 2,
#          'treated': 2,
#          'quantifying': 2,
#          'reward': 2,
#          'focus': 2,
#          'improvement': 2,
#          'clustered': 2,
#          'benchmark': 2,
#          'beginning': 2,
#          'survival': 2,
#          'demographic': 2,
#          'natural': 2,
#          'noise': 2,
#          'total': 2,
#          'topic': 2,
#          'locoregionally': 2,
#          'combination': 2,
#          'filtering': 2,
#          'crowdfunding': 2,
#          'strategic': 2,
#          'reram': 2,
#          'tcam': 2,
#          'frequent': 2,
#          'instant': 2,
#          'low': 2,
#          'war': 2,
#          'quantify': 2,
#          'boon': 2,
#          'cause': 2,
#          'headache': 2,
#          'pay': 2,
#          'swd': 2,
#          'unlock': 2,
#          'prevent': 2,
#          'addressing': 2,
#          'reprocessing': 2,
#          'fda': 2,
#          'council': 2,
#          'enhance': 2,
#          'require': 2,
#          'scientist': 2,
#          'turning': 2,
#          'society': 2,
#          'federal': 2,
#          'aim': 2,
#          'expert': 2,
#          'hardcover': 2,
#          'one': 2,
#          'really': 2,
#          'demystifying': 2,
#          'developmental': 2,
#          'save': 2,
#          'measured': 2,
#          'unstructured': 2,
#          'peril': 2,
#          'challenging': 2,
#          'hype': 2,
#          'matter': 2,
#          'rt': 2,
#          'variability': 2,
#          'identified': 2,
#          'lambda': 2,
#          'consortium': 2,
#          'oncology': 2,
#          'reimbursement': 2,
#          'part': 2,
#          'aadhaar': 2,
#          'like': 2,
#          'meaning': 2,
#          'mary': 2,
#          'come': 2,
#          'anesthesia': 2,
#          'precision': 2,
#          'guide': 2,
#          'europe': 2,
#          'envelopment': 2,
#          'infant': 2,
#          'karimi': 2,
#          'crc': 2,
#          'rescue': 2,
#          'flood': 2,
#          'sale': 2,
#          'effort': 2,
#          'difference': 2,
#          'driving': 2,
#          'progress': 2,
#          'crawling': 2,
#          'rapidminer': 2,
#          'bad': 2,
#          'networking': 2,
#          'stroke': 2,
#          'protective': 2,
#          'equipment': 2,
#          'stockpiling': 2,
#          'universal': 2,
#          'methodological': 2,
#          'campaign': 2,
#          'consequence': 2,
#          'segment': 2,
#          'pedestrian': 2,
#          'art': 2,
#          'discus': 2,
#          'related': 2,
#          'number': 2,
#          'idea': 2,
#          'gas': 2,
#          'learn': 2,
#          'rethinking': 2,
#          'promote': 2,
#          'providing': 2,
#          'european': 2,
#          'theoretic': 2,
#          'binary': 2,
#          'author': 2,
#          'labor': 2,
#          'moth': 2,
#          'flame': 2,
#          'bat': 2,
#          'daily': 1,
#          'fantasy': 1,
#          'know': 1,
#          'pervasive': 1,
#          'person': 1,
#          'event': 1,
#          'military': 1,
#          'civilian': 1,
#          'reused': 1,
#          'multiquery': 1,
#          'overcoming': 1,
#          'protecting': 1,
#          'virtualized': 1,
#          'tv': 1,
#          'audience': 1,
#          'diagram': 1,
#          'basalt': 1,
#          'intrusion': 1,
#          'oceanography': 1,
#          'enabler': 1,
#          'unsupervised': 1,
#          'scalability': 1,
#          'coordination': 1,
#          'medicare': 1,
#          'beneficiary': 1,
#          'medigap': 1,
#          ...})

# %%
word_count = dict()

for tag, counts in count.most_common(50):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# data : 1239
# big : 1112
# analytics : 113
# based : 102
# analysis : 97
# driven : 71
# system : 62
# using : 56
# approach : 56
# issue : 48
# learning : 48
# model : 46
# challenge : 44
# application : 40
# new : 39
# special : 37
# management : 36
# framework : 36
# algorithm : 36
# call : 34
# research : 34
# science : 34
# platform : 34
# paper : 32
# health : 31
# cloud : 30
# era : 30
# opportunity : 28
# network : 27
# machine : 26
# mining : 26
# processing : 26
# technology : 26
# computing : 25
# performance : 25
# method : 25
# earth : 25
# optimization : 24
# perspective : 24
# business : 24
# smart : 24
# distributed : 23
# information : 23
# use : 23
# review : 22
# process : 22
# world : 22
# intelligence : 21
# service : 21
# development : 20

# %% [markdown]
# ## 2. 데이터 탐색 - 히스토그램 그리기

# %%
sorted_Keys = sorted(word_count, key = word_count.get, reverse = True)
sorted_Values = sorted(word_count.values(), reverse = True)
plt.bar(range(len(word_count)), sorted_Values, align = 'center')
plt.xticks( range(len(word_count)), list(sorted_Keys), rotation = 85)
plt.show()

# %% [markdown]
# ###  - 'big', 'data'를 제외하고, 단어빈도 히스토그램 그리기

# %%
word_count2 = word_count
del word_count2['big']
del word_count2['data']

# %%
sorted_Keys = sorted(word_count2, key = word_count.get, reverse = True)
sorted_Values = sorted(word_count2.values(), reverse = True)
plt.bar(range(len(word_count2)), sorted_Values, align = 'center')
plt.xticks( range(len(word_count2)), list(sorted_Keys), rotation = 85)
plt.show()

# %% [markdown]
# # 6. 결과 시각화

# %%
all_files_data_concat['doc_count'] = 0
summary_year = all_files_data_concat.groupby('출판일', as_index = False)['doc_count'].count()
summary_year #출력하여 내용 확인
# Out:
#      출판일  doc_count
# 0   2003          1
# 1   2004          1
# 2   2011          5
# 3   2012         19
# 4   2013         50
# 5   2014        124
# 6   2015         92
# 7   2016        112
# 8   2017        129
# 9   2018        118
# 10  2019         90
# 11  2020        105
# 12  2021         90
# 13  2022         60
# 14  2023          4

# %%
plt.figure(figsize = (12, 5))
plt.xlabel("year")
plt.ylabel("doc-count")
plt.grid(True)
plt.plot(range(len(summary_year)), summary_year['doc_count'])
plt.xticks( range(len(summary_year)), [text for text in summary_year['출판일']])
plt.show()

# %%
stopwords = set(STOPWORDS)
wc = WordCloud(background_color = 'ivory', stopwords = stopwords,width = 800, height = 600)
cloud = wc.generate_from_frequencies(word_count)
plt.figure(figsize = (8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
cloud.to_file("8장_data/riss_bigdata_wordCloud.jpg")
