# %%
import pandas as pd

# %%
rel = pd.read_csv("filtered_kr_relevant.csv")

df = pd.DataFrame(rel)
# df.head(301)
# Out:
#                                       title     date  \
# 0    LIG넥스원-보스반도체, 드론·로봇향 피지컬 AI 솔루션 MOU 체결  2025-12
# 1           현대로템, 국내 최초 재사용 발사체용 메탄엔진 개발 착수  2025-12
# 2             첨단 항공엔진 개발을 위한 범부처 협의체 출범식 개최  2025-12
# 3                                 PKA의 방어대책  2025-11
# 4                        에어버스, 한국에 테크 허브 설립  2025-11
# ..                                      ...      ...
# 296  정부세종컨벤션센터에서 대한민국 군수산업발전 컨퍼런스 및 전시회가 열려  2020-06
# 297            삼성전자, 갤럭시 S20 미군용 택티컬 에디션 공개  2020-05
# 298   앱 사고사진 찍으면 車 수리견적이 한화시스템, AI ‘언택트’ 기술  2020-05
# 299               2020년 전력화 되어 있는 자위대 핵심 전력  2020-04
# 300                      중형전술트럭 기아자동차와 계약체결  2020-04
#
#                                                    url  \
# 0    http://www.defensetoday.kr/news/articleView.ht...
# 1    http://www.defensetoday.kr/news/articleView.ht...
# 2    http://www.defensetoday.kr/news/articleView.ht...
# 3    http://www.defensetoday.kr/news/articleView.ht...
# ...
