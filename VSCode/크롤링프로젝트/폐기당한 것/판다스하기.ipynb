# %%
import pandas as pd

# %%
rel = pd.read_csv("tech_matching_v5_data_matched_kr.csv")

df = pd.DataFrame(rel)
df
# Out:
#                                          kr_technology  kr_date domain  \
# 0                                     피지컬 AI, 온디바이스 AI  2025-12  항공/공군
# 1                                      재사용 우주발사체용 메탄엔진      NaN     우주
# 2                                              첨단 항공엔진      NaN  항공/공군
# 3    ['KF-21 전투기', 'FA-50 경공격기', '수리온 헬기', 'LAH 경무장...      NaN  항공/공군
# 4                                               수소전기트램      NaN  육상/지상
# ..                                                 ...      ...    ...
# 284                  ['M72 66mm LAW', 'Panzerfaust 3']  1970-06  육상/지상
# 285                    ['중형전술차량', '차기 표준차량(2.5톤/5톤급)']  2021-06  육상/지상
# 286                                          민수용 차량 도입  2012-12  육상/지상
# 287  ['K1A 기관단총', 'K-15 경기관총', 'K2C1 자동소총', 'KSPW(K...  2019-08  육상/지상
# 288                              인공지능(AI), 스마트 안전관리 체계  2019-08  육상/지상
#
#       core_technology                                      us_technology  \
# ...
