# %% [markdown]
# 크롤러가 가져온 파일을 모두 pdf로 통일(변환)

# %%
! pip install opencv-python
! pip install matplotlib
! pip install pytesseract
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2.3.0,>=2 (from opencv-python)
#   Downloading numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---- ----------------------------------- 4.2/39.0 MB 90.2 MB/s eta 0:00:01
#    -------- ------------------------------- 8.4/39.0 MB 107.0 MB/s eta 0:00:01
#    -------------- ------------------------- 13.8/39.0 MB 108.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 17.1/39.0 MB 108.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 22.4/39.0 MB 93.9 MB/s eta 0:00:01
#    --------------------------- ------------ 26.4/39.0 MB 108.8 MB/s eta 0:00:01
#    ------------------------------- -------- 30.5/39.0 MB 93.0 MB/s eta 0:00:01
#    ------------------------------------ --- 35.3/39.0 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  38.7/39.0 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  39.0/39.0 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  39.0/39.0 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------- 39.0/39.0 MB 46.7 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ------- -------------------------------- 2.5/12.9 MB 78.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.7/12.9 MB 90.2 MB/s eta 0:00:01
#    ------------------------------- -------- 10.3/12.9 MB 93.0 MB/s eta 0:00:01
#    --------------------------------- ------ 10.8/12.9 MB 65.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.2/12.9 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------------  12.9/12.9 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 40.9 MB/s eta 0:00:00
# Installing collected packages: numpy, opencv-python
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.0
#     Uninstalling numpy-2.4.0:
#       Successfully uninstalled numpy-2.4.0
# Successfully installed numpy-2.2.6 opencv-python-4.12.0.88
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/52.8 kB ? eta -:--:--
#      ----------------------------- -------- 41.0/52.8 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 52.8/52.8 kB 458.0 kB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp311-cp311-win_amd64.whl.metadata (116 kB)
#      ---------------------------------------- 0.0/116.4 kB ? eta -:--:--
#      -------------------------------------- 116.4/116.4 kB 3.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.0.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.4/8.1 MB 30.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 49.9 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 65.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 58.0 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
#    ---------------------------------------- 0.0/225.2 kB ? eta -:--:--
#    --------------------------------------- 225.2/225.2 kB 13.4 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 154.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
#    ---------------------------------------- 0.0/73.8 kB ? eta -:--:--
#    ---------------------------------------- 73.8/73.8 kB 4.2 MB/s eta 0:00:00
# Downloading pillow-12.0.0-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ----------- ---------------------------- 2.1/7.0 MB 129.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.1/7.0 MB 129.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.1/7.0 MB 129.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.1/7.0 MB 129.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.1/7.0 MB 129.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.9/7.0 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 23.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 22.3 MB/s eta 0:00:00
# Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.8 kB ? eta -:--:--
#    ---------------------------------------- 121.8/121.8 kB ? eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.0.0 pyparsing-3.3.1
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\user\appdata\roaming\python\python311\site-packages (from pytesseract) (25.0)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pytesseract) (12.0.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.8-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.6 kB ? eta -:--:--
#      ----------------- -------------------- 20.5/43.6 kB 682.7 kB/s eta 0:00:01
#      -------------------------------------- 43.6/43.6 kB 538.0 kB/s eta 0:00:00
# Collecting pdfminer.six==20251107 (from pdfplumber)
#   Downloading pdfminer_six-20251107-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pdfplumber) (12.0.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-5.2.0-py3-none-win_amd64.whl.metadata (67 kB)
#      ---------------------------------------- 0.0/67.8 kB ? eta -:--:--
#      ------------------------------------ --- 61.4/67.8 kB 1.6 MB/s eta 0:00:01
#      ---------------------------------------- 67.8/67.8 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pdfminer.six==20251107->pdfplumber) (3.4.4)
# Collecting cryptography>=36.0.0 (from pdfminer.six==20251107->pdfplumber)
#   Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber) (2.23)
# Downloading pdfplumber-0.11.8-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.0 kB ? eta -:--:--
#    ---------------------------------------- 60.0/60.0 kB 3.3 MB/s eta 0:00:00
# Downloading pdfminer_six-20251107-py3-none-any.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.6 MB 16.2 MB/s eta 0:00:01
#    -------- ------------------------------- 1.2/5.6 MB 14.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.7/5.6 MB 11.8 MB/s eta 0:00:01
#    ------------ --------------------------- 1.8/5.6 MB 9.6 MB/s eta 0:00:01
#    ------------- -------------------------- 1.9/5.6 MB 8.1 MB/s eta 0:00:01
#    ------------- -------------------------- 1.9/5.6 MB 8.1 MB/s eta 0:00:01
#    -------------- ------------------------- 2.0/5.6 MB 6.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.3/5.6 MB 6.4 MB/s eta 0:00:01
#    ------------------ --------------------- 2.6/5.6 MB 6.4 MB/s eta 0:00:01
#    --------------------- ------------------ 3.0/5.6 MB 6.6 MB/s eta 0:00:01
#    -------------------------- ------------- 3.7/5.6 MB 7.2 MB/s eta 0:00:01
#    ------------------------------ --------- 4.4/5.6 MB 7.9 MB/s eta 0:00:01
#    ------------------------------------ --- 5.1/5.6 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  5.6/5.6 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 8.2 MB/s eta 0:00:00
# Downloading pypdfium2-5.2.0-py3-none-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.1 MB 3.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.9/3.1 MB 9.0 MB/s eta 0:00:01
#    -------------------- ------------------- 1.6/3.1 MB 9.8 MB/s eta 0:00:01
#    --------------------------- ------------ 2.1/3.1 MB 10.5 MB/s eta 0:00:01
#    ------------------------------ --------- 2.4/3.1 MB 9.5 MB/s eta 0:00:01
#    ------------------------------- -------- 2.4/3.1 MB 8.1 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.7/3.1 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  3.1/3.1 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 2.9 MB/s eta 0:00:00
# Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.7/3.5 MB 15.5 MB/s eta 0:00:01
#    --------------- ------------------------ 1.4/3.5 MB 14.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.0/3.5 MB 14.1 MB/s eta 0:00:01
#    ------------------------ --------------- 2.2/3.5 MB 11.4 MB/s eta 0:00:01
#    ------------------------ --------------- 2.2/3.5 MB 10.6 MB/s eta 0:00:01
#    ------------------------- -------------- 2.2/3.5 MB 7.9 MB/s eta 0:00:01
#    -------------------------- ------------- 2.3/3.5 MB 7.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.6/3.5 MB 6.9 MB/s eta 0:00:01
#    ------------------------------ --------- 2.7/3.5 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.0/3.5 MB 6.2 MB/s eta 0:00:01
#    -------------------------------------- - 3.4/3.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 6.2 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, cryptography, pdfminer.six, pdfplumber
# Successfully installed cryptography-46.0.3 pdfminer.six-20251107 pdfplumber-0.11.8 pypdfium2-5.2.0
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install pytesseract pdf2image pillow
# Out:
# Requirement already satisfied: pytesseract in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (0.3.13)
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pillow in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (12.0.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\user\appdata\roaming\python\python311\site-packages (from pytesseract) (25.0)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.17.0
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# step 1

# %%
import shutil

import pdfplumber
import os

# %%
params = ['국기연_발간물', '국방위_국정감사', '국방위_보도', '국방위_회의록']
SOURCE_DIR = f"C:/Users/user/OneDrive/Desktop/Desktop/VSCode/크롤링프로젝트/"   # PDF들이 흩어져 있는 최상위 폴더: 크롤링프로젝트

PDF_DIR = "변환됨"           # 모을 폴더

os.makedirs(PDF_DIR, exist_ok=True)

for root, dirs, files in os.walk(SOURCE_DIR):
    os.makedirs(dirs[params], exist_ok = True)
    for file in files:
        if file.lower().endswith(".pdf"):
            src = os.path.join(root, file)
            dst = os.path.join(PDF_DIR, file)

            # 같은 이름 파일 충돌 방지
            if os.path.exists(dst):
                name, ext = os.path.splitext(file)
                i = 1
                while os.path.exists(dst):
                    dst = os.path.join(PDF_DIR, f"{name}_{i}{ext}")
                    i += 1

            shutil.copy2(src, dst)

print("PDF 수집 완료")
# Out:
# PDF 수집 완료

# %%
#<위의 것 수정된 버전>
# 1. 설정
params = ['국기연_발간물', '국방위_국정감사', '국방위_보도', '국방위_회의록']
BASE_SOURCE_DIR = "C:/Users/user/OneDrive/Desktop/Desktop/VSCode/크롤링프로젝트"
BASE_OUTPUT_DIR = "변환됨"

os.makedirs(BASE_OUTPUT_DIR, exist_ok=True)

# 2. 각 카테고리(params)별로 순회
for category in params:
    source_path = os.path.join(BASE_SOURCE_DIR, category)
    output_path = os.path.join(BASE_OUTPUT_DIR, category)
    
    # 출력될 카테고리 폴더 생성 (예: 변환됨/국기연_발간물)
    os.makedirs(output_path, exist_ok=True)
    
    # 해당 폴더가 실제로 존재하는지 확인
    if not os.path.exists(source_path):
        print(f"경로를 찾을 수 없어 건너뜁니다: {source_path}")
        continue

    print(f"'{category}' 폴더 작업 시작...")

    # 3. 파일 순회
    for root, dirs, files in os.walk(BASE_SOURCE_DIR):
        for file in files:
            if file.lower().endswith(".pdf"):
                src = os.path.join(root, file)
                dst = os.path.join(BASE_OUTPUT_DIR, file)
                
                # # 파일명에서 확장자 제외하고 추출
                # file_name_only = os.path.splitext(file)[0]
                
                # # 목적지 파일 경로 (여기에 OCR 결과 저장 로직이 들어감)
                # dst_txt_path = os.path.join(output_path, f"{file_name_only}.txt")

                # # 중복 이름 방지 로직
                # counter = 1
                # original_dst = dst_txt_path
                # while os.path.exists(dst_txt_path):
                #     dst_txt_path = os.path.join(output_path, f"{file_name_only}_{counter}.txt")
                #     counter += 1

                # 같은 이름 파일 충돌 방지
                if os.path.exists(dst):
                    name, ext = os.path.splitext(file)
                    i = 1
                    while os.path.exists(dst):
                        dst = os.path.join(PDF_DIR, f"{name}_{i}{ext}")
                        i += 1
                shutil.copy2(src, dst)

                # -------------------------------------------------------
                # [OCR 및 저장 구간]
                # 여기에 실제 PDF to TXT 변환 함수를 넣으시면 됩니다.
                # 예시: dummy_ocr_save(src, dst_txt_path)
                # 지금은 구조 확인을 위해 빈 파일 생성으로 대체합니다.
                # with open(dst_txt_path, 'w', encoding='utf-8') as f:
                #     f.write(f"{src}에서 추출될 내용이 여기 저장됩니다.")
                # -------------------------------------------------------

print("작업 완료! '변환됨' 폴더를 확인하세요.")
# Out:
# '국기연_발간물' 폴더 작업 시작...
# '국방위_국정감사' 폴더 작업 시작...
# '국방위_보도' 폴더 작업 시작...
# '국방위_회의록' 폴더 작업 시작...
# 작업 완료! '변환됨' 폴더를 확인하세요.

# %%
PDF_DIR = "pdf모음"
OUTPUT = "merged.txt"

with open(OUTPUT, "w", encoding="utf-8") as out:
    for file in os.listdir(PDF_DIR):
        if file.endswith(".pdf"):
            path = os.path.join(PDF_DIR, file)
            out.write(f"\n\n===== < {file} > =====\n")
            
            with pdfplumber.open(path) as pdf:
                for page in pdf.pages:
                    text = page.extract_text()
                    if text:
                        out.write(text + "\n")

# %% [markdown]
# step 2

# %%
from pdf2image import convert_from_path
import pytesseract

# %%
# pytesseract 사용을 위한 코드 추가
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract.exe'

# %%
images = convert_from_path("sample.pdf")

text_all = ""
for img in images:
    text = pytesseract.image_to_string(img, lang="kor+eng")
    text_all += text + "\n"

with open("ocr_result.txt", "w", encoding="utf-8") as f:
    f.write(text_all)

# %% [markdown]
# step 3 (후처리)

# %%
import re

# %%
text = open("merged.txt", encoding="utf-8").read()

# 불필요한 공백 제거
text = re.sub(r"\n{3,}", "\n\n", text)

with open("cleaned.txt", "w", encoding="utf-8") as f:
    f.write(text)

# %% [markdown]
# 합친 버전

# %%
import os
import pdfplumber
import pytesseract
from pdf2image import convert_from_path

# 1. 설정
params = ['국기연_발간물', '국방위_국정감사', '국방위_보도', '국방위_회의록']
BASE_SOURCE_DIR = "C:/Users/user/OneDrive/Desktop/Desktop/VSCode/크롤링프로젝트"
BASE_OUTPUT_DIR = "변환됨"
MERGED_FILE = "merged.txt"

# Tesseract 실행 경로 설정
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract.exe'

os.makedirs(BASE_OUTPUT_DIR, exist_ok=True)

def get_pdf_text(path):
    """텍스트 추출을 먼저 시도하고, 안되면 OCR을 진행하는 함수"""
    full_text = ""
    
    # [방법 1] pdfplumber로 텍스트 직접 추출 시도
    with pdfplumber.open(path) as pdf:
        for page in pdf.pages:
            t = page.extract_text()
            if t:
                full_text += t + "\n"
    
    # [방법 2] 만약 추출된 텍스트가 너무 적다면 (스캔된 이미지 PDF일 경우) OCR 실행
    if len(full_text.strip()) < 50:  # 기준은 조정 가능
        print(f"      > 텍스트가 없거나 적음. OCR 진행 중: {os.path.basename(path)}")
        try:
            # PDF를 이미지로 변환 (기본 200dpi)
            images = convert_from_path(path)
            full_text = ""
            for img in images:
                # 한국어와 영어 동시 인식
                text = pytesseract.image_to_string(img, lang="kor+eng")
                full_text += text + "\n"
        except Exception as e:
            print(f"      ❌ OCR 에러: {e}")
            
    return full_text

# 전체 통합 파일을 위한 오픈
with open(MERGED_FILE, "w", encoding="utf-8") as merged_out:
    
    for category in params:
        source_path = os.path.join(BASE_SOURCE_DIR, category)
        output_path = os.path.join(BASE_OUTPUT_DIR, category)
        
        if not os.path.exists(source_path):
            print(f"⚠️ 폴더 없음: {source_path}")
            continue

        os.makedirs(output_path, exist_ok=True)
        print(f"\n📂 '{category}' 카테고리 작업 시작...")

        for root, dirs, files in os.walk(source_path):
            for file in files:
                if file.lower().endswith(".pdf"):
                    src_path = os.path.join(root, file)
                    file_name_only = os.path.splitext(file)[0]
                    dst_txt_path = os.path.join(output_path, f"{file_name_only}.txt")

                    print(f"   📄 처리 중: {file}")
                    
                    # 텍스트 추출 실행
                    content = get_pdf_text(src_path)

                    # 1. 개별 txt 파일 저장
                    with open(dst_txt_path, "w", encoding="utf-8") as f:
                        f.write(content)

                    # 2. merged.txt에 추가 저장
                    merged_out.write(f"\n\n===== < {category} / {file} > =====\n")
                    merged_out.write(content)

print(f"\n✨ 모든 작업 완료!")
print(f"- 개별 TXT: {BASE_OUTPUT_DIR} 폴더 내부")
print(f"- 통합 TXT: {MERGED_FILE}")
# Out:
# 📂 '국기연_발간물' 카테고리 작업 시작...
#    📄 처리 중: '21_'35 핵심기술기획서(일반본, DTiMS 탑재용).pdf
#    📄 처리 중: '23-'37 국방기술기획서 일반본.pdf
#    📄 처리 중: '24-'38 국방기술기획서(일반본).pdf
#    📄 처리 중: '25-'39 국방기술기획서 일반본.pdf
#    📄 처리 중: `17 ~ `31 핵심기술기획서 일반본.pdf
#    📄 처리 중: ’18~’32 핵심기술기획서.pdf
#    📄 처리 중: ’19~’33 핵심기술기획서.pdf
#    📄 처리 중: 국방기술진흥연구소 - 22-36 국방기술기획서 일반본.pdf
#
# 📂 '국방위_국정감사' 카테고리 작업 시작...
#    📄 처리 중: 02국감결과보고서.pdf
#    📄 처리 중: 03국감결과보고서[1].pdf
#    📄 처리 중: 04국감결과보고서(최종의결).pdf
#    📄 처리 중: 05국감결과보고서(최종)(05.11.29).pdf
#    📄 처리 중: 2000국감결과보고.pdf
#    📄 처리 중: 2001년도국감결과보고서.pdf
#    📄 처리 중: 2006국정감사결과보고서(최종의결).pdf
#    📄 처리 중: 2007국정감사결과보고서.pdf
#    📄 처리 중: 2008국정감사결과보고서(최종-유인).pdf
#    📄 처리 중: 2009국정감사결과보고서.pdf
#    📄 처리 중: 2015년도 국정감사 결과보고서.pdf
#    📄 처리 중: 2017_국방위원회_국정감사 결과보고서(최종본).pdf
#    📄 처리 중: 2018년도 국정감사 결과보고서.pdf
#    📄 처리 중: 2020년도 국정감사결과보고서.pdf
#    📄 처리 중: 2022년도 국방위원회 국정감사 결과보고서.pdf
#    📄 처리 중: 2024년도 국정감사 결과보고서(국방위원회).pdf
#    📄 처리 중: 97국감결과.pdf
#    📄 처리 중: 98국감결과보고.pdf
#    📄 처리 중: 99년도국정감사결과보고서.pdf
#    📄 처리 중: 국감결과보고서(2011)최종.pdf
#    📄 처리 중: 국정감사결과시정및처리사항.pdf
#
# 📂 '국방위_보도' 카테고리 작업 시작...
#    📄 처리 중: [보도자료] 국방위원회 한미연합군사령부 전시지휘소 현장방문 (1).pdf
#    📄 처리 중: [보도자료] 국방위원회 한미연합군사령부 전시지휘소 현장방문.pdf
#    📄 처리 중: [보도자료] 국방위원회, 소관 부처의 2020회계연도 결산 의결 (1).pdf
#    📄 처리 중: [보도자료] 국방위원회, 소관 부처의 2020회계연도 결산 의결.pdf
#    📄 처리 중: [보도자료] 국회 국방위 대표단, K-방산 세일즈 외교 성공적으로 마치고 귀국 (1).pdf
#    📄 처리 중: [보도자료] 국회 국방위 대표단, K-방산 세일즈 외교 성공적으로 마치고 귀국.pdf
#    📄 처리 중: [보도자료] 국회 국방위 병역법 개정관련 국민 여론조사 실시 (1).pdf
#    📄 처리 중: [보도자료] 국회 국방위 병역법 개정관련 국민 여론조사 실시.pdf
#    📄 처리 중: [보도자료] 국회 국방위, NATO 의회연맹 대표단 면담 (1).pdf
#    📄 처리 중: [보도자료] 국회 국방위, NATO 의회연맹 대표단 면담.pdf
#    📄 처리 중: [보도자료] 국회 국방위, 軍 출산 육아 지원 정책 개선 간담회 (1).pdf
#    📄 처리 중: [보도자료] 국회 국방위, 軍 출산 육아 지원 정책 개선 간담회.pdf
#    📄 처리 중: [보도자료] 국회 국방위, 북한의 탄도미사일 도발 규탄 및 중단 촉구 (1).pdf
#    📄 처리 중: [보도자료] 국회 국방위, 북한의 탄도미사일 도발 규탄 및 중단 촉구.pdf
#    📄 처리 중: [보도자료] 국회 국방위, 유럽의회 대표단 면담 (1).pdf
#    📄 처리 중: [보도자료] 국회 국방위, 유럽의회 대표단 면담.pdf
#    📄 처리 중: [보도자료] 국회 국방위, 전임 한미연합사령관 3인 면담 (1).pdf
#    📄 처리 중: [보도자료] 국회 국방위, 전임 한미연합사령관 3인 면담.pdf
#    📄 처리 중: [보도자료] 국회 국방위, 한국형 3축체계 구축을 위한 예산 의결 (1).pdf
#    📄 처리 중: [보도자료] 국회 국방위, 한국형 3축체계 구축을 위한 예산 의결.pdf
#    📄 처리 중: [보도자료] 국회 국방위원회, 남수단 한빛부대 현장방문 (1).pdf
#    📄 처리 중: [보도자료] 국회 국방위원회, 남수단 한빛부대 현장방문.pdf
#    📄 처리 중: [보도자료] 소령 정년, 45세에서 50세로 5년 연장 (1).pdf
#    📄 처리 중: [보도자료] 소령 정년, 45세에서 50세로 5년 연장.pdf
#
# 📂 '국방위_회의록' 카테고리 작업 시작...
#    📄 처리 중: 제22대 제416회 1차 국방위원회.pdf
#    📄 처리 중: 제22대 제417회 1차 국방위원회.pdf
#    📄 처리 중: 제22대 제417회 2차 국방위원회.pdf
#    📄 처리 중: 제22대 제418회 10차 국방위원회.pdf
#    📄 처리 중: 제22대 제418회 11차 국방위원회.pdf
#    📄 처리 중: 제22대 제418회 1차 국방위원회 법률안심사소위원회.pdf
#    📄 처리 중: 제22대 제418회 1차 국방위원회 예산결산심사소위원회.pdf
#    📄 처리 중: 제22대 제418회 1차 국방위원회.pdf
#    📄 처리 중: 제22대 제418회 2차 국방위원회 법률안심사소위원회.pdf
#    📄 처리 중: 제22대 제418회 2차 국방위원회 예산결산심사소위원회.pdf
#    📄 처리 중: 제22대 제418회 2차 국방위원회.pdf
#    📄 처리 중: 제22대 제418회 3차 국방위원회 법률안심사소위원회.pdf
#    📄 처리 중: 제22대 제418회 3차 국방위원회 예산결산심사소위원회.pdf
#    📄 처리 중: 제22대 제418회 3차 국방위원회.pdf
#    📄 처리 중: 제22대 제418회 4차 국방위원회 법률안심사소위원회.pdf
#    📄 처리 중: 제22대 제418회 4차 국방위원회 예산결산심사소위원회.pdf
#    📄 처리 중: 제22대 제418회 4차 국방위원회.pdf
#    📄 처리 중: 제22대 제418회 5차 국방위원회.pdf
#    📄 처리 중: 제22대 제418회 6차 국방위원회.pdf
#    📄 처리 중: 제22대 제418회 7차 국방위원회.pdf
#    📄 처리 중: 제22대 제418회 8차 국방위원회.pdf
#    📄 처리 중: 제22대 제418회 9차 국방위원회.pdf
#    📄 처리 중: 제22대 제419회 1차 국방위원회.pdf
#    📄 처리 중: 제22대 제422회 1차 국방위원회 법률안심사소위원회.pdf
#    📄 처리 중: 제22대 제422회 1차 국방위원회.pdf
#    📄 처리 중: 제22대 제422회 2차 국방위원회 법률안심사소위원회.pdf
#    📄 처리 중: 제22대 제422회 2차 국방위원회.pdf
#    📄 처리 중: 제22대 제422회 3차 국방위원회.pdf
#    📄 처리 중: 제22대 제424회 1차 국방위원회 법률안심사소위원회.pdf
#    📄 처리 중: 제22대 제426회 1차 국방위원회 예산결산심사소위원회.pdf
#    📄 처리 중: 제22대 제426회 1차 국방위원회.pdf
#    📄 처리 중: 제22대 제426회 2차 국방위원회.pdf
#    📄 처리 중: 제22대 제427회 1차 국방위원회.pdf
#    📄 처리 중: 제22대 제427회 2차 국방위원회.pdf
#    📄 처리 중: 제22대 제428회 1차 국방위원회 예산결산심사소위원회.pdf
#    📄 처리 중: 제22대 제428회 1차 국방위원회.pdf
#    📄 처리 중: 제22대 제429회 1차 국방위원회 군복지개선소위원회.pdf
#    📄 처리 중: 제22대 제429회 1차 국방위원회 법률안심사소위원회.pdf
#    📄 처리 중: 제22대 제429회 1차 국방위원회 예산결산심사소위원회.pdf
#    📄 처리 중: 제22대 제429회 1차 국방위원회.pdf
#    📄 처리 중: 제22대 제429회 2차 국방위원회 법률안심사소위원회.pdf
#    📄 처리 중: 제22대 제429회 2차 국방위원회 예산결산심사소위원회.pdf
#    📄 처리 중: 제22대 제429회 2차 국방위원회.pdf
#    📄 처리 중: 제22대 제429회 3차 국방위원회 예산결산심사소위원회.pdf
#    📄 처리 중: 제22대 제429회 3차 국방위원회.pdf
#    📄 처리 중: 제22대 제429회 4차 국방위원회.pdf
#    📄 처리 중: 제22대 제429회 5차 국방위원회.pdf
#    📄 처리 중: 제22대 제429회 6차 국방위원회.pdf
#    📄 처리 중: 제22대 제429회 7차 국방위원회.pdf
#    📄 처리 중: 제22대 제429회 8차 국방위원회.pdf
#
# ✨ 모든 작업 완료!
# - 개별 TXT: 변환됨 폴더 내부
# - 통합 TXT: merged.txt
