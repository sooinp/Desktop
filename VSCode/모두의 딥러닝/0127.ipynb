# %%
import sys
# !{sys.executable} -m pip install pandas matplotlib seaborn scipy tensorflow keras

# %%
# 1. 필수 라이브러리 강제 설치 및 커널 인식
! pip install pandas matplotlib seaborn scipy

# 2. 한글 깨짐 방지 설정 (Windows 기준)
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 3. 설치 후 커널을 재시작해야 할 수도 있습니다.
print("설치 완료! 이제 상단 'Restart Kernel'을 누르고 아래 코드를 실행하세요.")
# Out:
# 설치 완료! 이제 상단 'Restart Kernel'을 누르고 아래 코드를 실행하세요.
# 'pip'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
! git clone https://github.com/taehojo/data.git
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: DLL 초기화 루틴을 실행할 수 없습니다.
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df = pd.read_csv('course_completion_raw_1000.csv')
df
# Out:
#      user_id          watch_ratio  weekly_minutes  login_days_7d  sessions_7d  \
# 0    U180325   0.6442216086075401      128.678281              3            7
# 1    U796559   0.4182103636005199      155.622686              0           16
# 2    U689113   0.5728484529558512       48.748187              5           15
# 3    U494990  0.44506089232258156      230.454431              5           11
# 4    U489713   0.7892551378540293      146.199604              5           11
# ..       ...                  ...             ...            ...          ...
# 995  U663410  0.26533441285146137      162.421402              5           12
# 996  U573738  0.40325743245637996      115.762365              0           14
# 997  U424591   0.2369796757895418      159.548889              6            9
# 998  U965593   0.6527613447394385       79.483340              5            8
# 999  U561464   0.7042677881525318      157.180143              7           13
#
# ...

# %%
print('user_id |', type(df['user_id'][0]))
print('watch_ratio |', type(df['watch_ratio'][0]))
print('weekly_minutes |', type(df['weekly_minutes'][0]))
print('login_days_7d |', type(df['login_days_7d'][0]))
print('sessions_7d |', type(df['sessions_7d'][0]))
print('assignment_submit_rate |', type(df['assignment_submit_rate'][0]))
print('quiz_avg |', type(df['quiz_avg'][0]))
print('forum_posts_30d |', type(df['forum_posts_30d'][0]))
print('device_main |', type(df['device_main'][0]))
print('signup_channel |', type(df['signup_channel'][0]))
print('paid |', type(df['paid'][0]))
print('signup_date |', type(df['signup_date'][0]))
print('last_active_date |', type(df['last_active_date'][0]))
print('completed |', type(df['completed'][0]))
# Out:
# user_id | <class 'str'>
# watch_ratio | <class 'str'>
# weekly_minutes | <class 'numpy.float64'>
# login_days_7d | <class 'numpy.int64'>
# sessions_7d | <class 'numpy.int64'>
# assignment_submit_rate | <class 'numpy.float64'>
# quiz_avg | <class 'str'>
# forum_posts_30d | <class 'numpy.int64'>
# device_main | <class 'str'>
# signup_channel | <class 'str'>
# paid | <class 'str'>
# signup_date | <class 'str'>
# last_active_date | <class 'str'>
# completed | <class 'numpy.int64'>

# %%
df['watch_ratio'] = df['watch_ratio'].astype(str).str.replace(r'[^0-9.]', '', regex=True)
df['watch_ratio'] = df['watch_ratio'].astype(float)
df.loc[df['watch_ratio'] > 1, 'watch_ratio'] = df['watch_ratio'] / 100
df['watch_ratio'] = df['watch_ratio'].round(2)
# df['watch_ratio']
# Out:
# 0      0.64
# 1      0.42
# 2      0.57
# 3      0.45
# 4      0.79
#        ...
# 995    0.27
# 996    0.40
# 997    0.24
# 998    0.65
# 999    0.70
# Name: watch_ratio, Length: 1000, dtype: float64

# %%
df['weekly_minutes'] = df['weekly_minutes'].astype(str).str.replace(r'[^0-9.]', '', regex=True)
df['weekly_minutes'] = df['weekly_minutes'].astype(float)
df['weekly_minutes'] = df['weekly_minutes'].round(0).astype(int) #정수 반올림(분)
# df['weekly_minutes']
# Out:
# 0      129
# 1      156
# 2       49
# 3      230
# 4      146
#       ...
# 995    162
# 996    116
# 997    160
# 998     79
# 999    157
# Name: weekly_minutes, Length: 1000, dtype: int64

# %%
a = df['login_days_7d'].unique()
print(sorted(a))
b = df['sessions_7d'].unique()
print(sorted(b))
c = df['forum_posts_30d'].unique()
print(sorted(c))
# Out:
# [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7)]
# [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21)]
# [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5)]

# %%
df['assignment_submit_rate'] = df['assignment_submit_rate'].astype(str).str.replace(r'[^0-9.]', '', regex=True)
df['assignment_submit_rate'] = df['assignment_submit_rate'].astype(float)
df.loc[df['assignment_submit_rate'] > 1, 'assignment_submit_rate'] = df['assignment_submit_rate'] / 100
df['assignment_submit_rate'] = df['assignment_submit_rate'].round(2)
# df['assignment_submit_rate']
# Out:
# 0      0.06
# 1      0.49
# 2      0.17
# 3      0.63
# 4      0.11
#        ...
# 995    0.92
# 996    0.56
# 997    0.23
# 998    0.47
# 999    0.51
# Name: assignment_submit_rate, Length: 1000, dtype: float64

# %%
df['quiz_avg'] = df['quiz_avg'].astype(str).str.replace(r'[^0-9.]', '', regex=True).str.strip()
df['quiz_avg'] = pd.to_numeric(df['quiz_avg'], errors='coerce')
df['quiz_avg'] = df['quiz_avg'].round(0)
df['quiz_avg']
# Out:
# 0      100.0
# 1       51.0
# 2       79.0
# 3       98.0
# 4       56.0
#        ...
# 995     58.0
# 996     71.0
# 997     67.0
# 998     72.0
# 999     95.0
# Name: quiz_avg, Length: 1000, dtype: float64

# %%
d = df['device_main'].unique()
print(sorted(d))

d_dic = {
    ' MOBILE': 'mobile',
    ' mobile': 'mobile',
    'MOBILE': 'mobile',
    'mobile': 'mobile',
    ' PC': 'pc',
    ' pc': 'pc',
    'PC': 'pc',
    'pc': 'pc',
    ' tablet': 'tablet',
    'TABLET': 'tablet',
    'tablet': 'tablet',
}
df['device_main'] = df['device_main'].replace(d_dic)
d = df['device_main'].unique()
print(sorted(d))
# Out:
# [' MOBILE', ' PC', ' mobile', ' pc', ' tablet', 'MOBILE', 'PC', 'TABLET', 'mobile', 'pc', 'tablet']
# ['mobile', 'pc', 'tablet']

# %%
df['signup_channel'].unique()
# Out:
# <StringArray>
# ['ad', 'sns', 'search', 'referral']
# Length: 4, dtype: str

# %%
d_dic2 = { # 0 = True, 1 = False임
    '0': 0,
    'True': 0,
    'Y': 0,
    '1': 1,
    'False': 1,
    'N': 1,
}
df['paid'] = df['paid'].replace(d_dic2)

print(df['paid'].unique())
print()
print(df[df['paid'].isna()])
print("\n결측치 개수:", df['paid'].isna().sum())
df = df.dropna(subset=['paid']) #결측치 아예 제거함
# Out:
# [0 1]
#
# Empty DataFrame
# Columns: [user_id, watch_ratio, weekly_minutes, login_days_7d, sessions_7d, assignment_submit_rate, quiz_avg, forum_posts_30d, device_main, signup_channel, paid, signup_date, last_active_date, completed]
# Index: []
#
# 결측치 개수: 0

# %%
df['signup_date'].unique()
# Out:
# <StringArray>
# ['2025-08-26', '2025-03-25', '2025-08-27', '2025-06-25', '2025-01-09',
#  '2025-11-30', '2025-10-17', '2025-08-13', '2025-09-02', '2025-07-30',
#  ...
#  '2025-03-19', '2025-01-24', '2025-08-07', '2025-01-02', '2025-12-12',
#  '2025-04-11', '2025-10-28', '2025-05-22', '2025-04-13', '2025-10-14']
# Length: 341, dtype: str

# %%
df['last_active_date'].unique()
# Out:
# <StringArray>
# ['2025-09-13', '2025-09-20', '2025-10-23', '2025-12-13', '2025-02-26',
#  '2026-01-17', '2025-10-21', '2025-10-31', '2026-02-20', '2026-01-07',
#  ...
#  '2025-07-19', '2025-06-18', '2026-03-17', '2025-03-02', '2026-02-03',
#  '2025-12-06', '2026-02-24', '2026-03-24', '2025-04-25', '2026-04-02']
# Length: 401, dtype: str

# %%
d_dic3 = {
    '중도 포기': 0,
    '완강': 1,
}
df['completed'] = df['completed'].replace(d_dic3)
print(df['completed'].unique())
# Out:
# [0 1]

# %%
date_cols = ['signup_date', 'last_active_date']

for col in date_cols:
    # errors='coerce'를 설정하면 잘못된 날짜 형식은 NaT(결측치)로 처리되어 안전
    df[col] = pd.to_datetime(df[col], errors='coerce')

print(df[date_cols].info())
print(df[date_cols].head())
# Out:
# <class 'pandas.DataFrame'>
# Index: 963 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   signup_date       963 non-null    datetime64[us]
#  1   last_active_date  963 non-null    datetime64[us]
# dtypes: datetime64[us](2)
# memory usage: 22.6 KB
# None
#   signup_date last_active_date
# 0  2025-08-26       2025-09-13
# 1  2025-03-25       2025-09-20
# 2  2025-08-27       2025-10-23
# 3  2025-06-25       2025-12-13
# 4  2025-01-09       2025-02-26

# %%
df
# Out:
#      user_id  watch_ratio  weekly_minutes  login_days_7d  sessions_7d  \
# 0    U180325         0.64             129              3            7
# 1    U796559         0.42             156              0           16
# 2    U689113         0.57              49              5           15
# 3    U494990         0.45             230              5           11
# 4    U489713         0.79             146              5           11
# ..       ...          ...             ...            ...          ...
# 995  U663410         0.27             162              5           12
# 996  U573738         0.40             116              0           14
# 997  U424591         0.24             160              6            9
# 998  U965593         0.65              79              5            8
# 999  U561464         0.70             157              7           13
#
#      assignment_submit_rate  quiz_avg  forum_posts_30d device_main  \
# ...

# %%
drop_cols = ['user_id', 'device_main', 'signup_channel', 'signup_date', 'last_active_date']
df_ml = df.drop(columns=drop_cols)

X = df_ml.drop(columns=['completed']).astype(float) # 타겟 제외 모두 X에 집어넣음
n_features = X.shape[1]
y = df_ml['completed']

model = Sequential()
model.add(Dense(12, input_dim = n_features, activation = 'relu', name = 'Dense_1'))
model.add(Dense(8, activation = 'relu', name = 'Dense_2'))
model.add(Dense(1, activation = 'sigmoid', name = 'Dense_3'))
model.summary()

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
history = model.fit(X, y, epochs = 100, batch_size = 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 8
#       5 n_features = X.shape[1]
#       6 y = df_ml['completed']
# ----> 8 model = Sequential()
#       9 model.add(Dense(12, input_dim = n_features, activation = 'relu', name = 'Dense_1'))
#      10 model.add(Dense(8, activation = 'relu', name = 'Dense_2'))
#
# NameError: name 'Sequential' is not defined
